# %%
#create a contact list
#use a list to create multiple contacts
#Each contact can be represented as a dictionary with keys like "name", "phone", and "email".
contacts = []

#create function to add contact
def add_contact():
   name = input("Enter Name")
   phone = input("Enter Phone No")
   email = input("Enter Email Address")
   contact = {"name": name, "phone": phone, "email": email}
   contacts.append(contact)
   print(f"Contact {name} added succesfully!")

#create function to view contact
#This checks if the contacts list is empty. The not operator returns True if the list is empty.
def view_contact():
  if not contacts:
    print("No contacts found")
#This line starts a loop that iterates over each contact in the contacts list. The enumerate() function provides both the index (idx) and the contact (contact). The start=1 argument ensures that the index starts at 1 instead of 0, making the display more user-friendly.
  else:
    for idx, contact in enumerate(contacts, start=1):
      print(f"{idx}. Name: {contact['name']}, Phone: {contact['phone']}, Email: {contact['email']}")

#create function update contact
def update_contact():
  name = input("Enter the name of the contact you want to update")
  for contact in contacts:
    if contact["name"].lower() == name.lower():
      print("Yeepi!, Contact found, Enter new details")
      new_phone = input("Enter new phone number")
      new_email = input("Enter new email address")
      contact["phone"] = new_phone
      contact["email"] = new_email
      print("Contact updated succesfully!")
      return
    print("Contact not found")

#create function delete contact
def delete_contact():
  name = input("Enter the name of the contact you want to delete")
  for contact in contacts:
    if contact["name"].lower() == name.lower():
      contacts.remove(contact)
      print("Contact deleted sucesfully")
      return
    print("contact not found")

#create function menu
def show_menu():
  while True:
    print("\nContact List Menu")
    print("1.Add Contact")
    print("2.view Contact")
    print("3.Update Contact")
    print("4.Delete Contact")
    print("5.Exit")
    choice = input("Choose an Option 1-5")

    if choice == "1":
      add_contact()
    elif choice == "2":
      view_contact()
    elif choice == "3":
      update_contact()
    elif choice == "4":
      delete_contact
    elif choice == "5":
      print("Exiting the App...")
      break
    else:
      print("Invalid choice. Please choose a valid option (1-5)")

show_menu()
# Out:
# Contact List Menu
# 1.Add Contact
# 2.view Contact
# 3.Update Contact
# 4.Delete Contact
# 5.Exit
# Choose an Option 1-52
# No contacts found
#
# Contact List Menu
# 1.Add Contact
# 2.view Contact
# 3.Update Contact
# 4.Delete Contact
# 5.Exit
# Choose an Option 1-5erick neo
# Invalid choice. Please choose a valid option (1-5)
#
# Contact List Menu
# 1.Add Contact
# 2.view Contact
# 3.Update Contact
# 4.Delete Contact
# 5.Exit
# Choose an Option 1-50710988978
# Invalid choice. Please choose a valid option (1-5)
#
# Contact List Menu
# 1.Add Contact
# 2.view Contact
# 3.Update Contact
# 4.Delete Contact
# 5.Exit
# Choose an Option 1-5atura@gmail.com
# Invalid choice. Please choose a valid option (1-5)
#
# Contact List Menu
# 1.Add Contact
# 2.view Contact
# 3.Update Contact
# 4.Delete Contact
# 5.Exit
# Choose an Option 1-5Fred Ksf
# Invalid choice. Please choose a valid option (1-5)
#
# Contact List Menu
# 1.Add Contact
# 2.view Contact
# 3.Update Contact
# 4.Delete Contact
# 5.Exit
# ...
