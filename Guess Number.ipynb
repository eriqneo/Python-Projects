# %%
#Import the random module to generate a random number
import random

# %%
# Generate a random number between 1 and 100.
random_number =random.randint(1, 100)

#Initialize a variable to keep track of the number of attempts.
attempts = 0

# Start a loop that continues until the user guesses correctly.
while True:
    #Prompt the user to enter the number
    guess = int(input("Guess the Number Between 1-100"))
    #Increament the attempts counter
    attempts += 1
    #check if the user is correct
    if guess < random_number:
      print("Too Low,Try Again")
    elif guess > random_number:
      print("Too High, Try Again")
    else:
      print(f"correct, The number is{random_number}")
      print(f"You took {attempts} attempts")
      break
# Out:
# Guess the Number Between 1-10067
# Too Low,Try Again
# Guess the Number Between 1-10074
# Too Low,Try Again
# Guess the Number Between 1-10081
# Too Low,Try Again
# Guess the Number Between 1-10093
# Too Low,Try Again
# Guess the Number Between 1-10099
# Too High, Try Again
# Guess the Number Between 1-10096
# Too High, Try Again
# Guess the Number Between 1-10095
# Too High, Try Again
# Guess the Number Between 1-10094
# correct, The number is94
# You took 8 attempts

# %%
|
