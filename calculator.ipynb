# %%
num1 = float(input("input first number"))
num2 = float(input("input second number"))


operation = input("choose an operation")

result = None  # Initialize result to None


if operation == "+":
    print(num1 +num2)
elif operation == "-":
    print(num1-num2)
if operation == "*":
    print(num1*num2)
elif operation == "/":
  #handle division by 0
    if num2 != 0:
       print(num1/num2)
    else:
        print("cannot divide by zero")

else:
    print("invalid operation")

if result is not None:  # Check if result has been calculated
    print("The Result is;", result)
# Out:
# input first number43
# input second number67
# choose an operation*
# 2881.0
